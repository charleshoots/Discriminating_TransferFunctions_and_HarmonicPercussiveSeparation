# %% [markdown]
# # Possible new QC issues with some stations.

# %% [markdown]
# #### -An issue that I never caught has shown up with Z6.11. The ZZ (ATaCR) coherences are not going to 1 at the notch as it should.
# #### -First noticed in the draft figures for the paper below
# <img src="./NB_Assets/3.28.25/2010.012.21.53.Mw7.0_ATaCR_Shallow_Z6.11.5836m.png" alt="A" width="600">

# %% [markdown]
# #### -This is despite the TF for this station not exhibiting any non-zero values in the TF after the notch, demonstrated by the TF plot output from atacr below.
# <img src="./NB_Assets/3.28.25/Z6.11.transfer_functions.png" alt="A" width="600">

# %% [markdown]
# #### -This plot below puts the two ideas above together and gets us closer to the issue at hand,
# #### -Namely, that the TFs are working correctly but that is not indicated by the ZZ coherence.
# #### -The top row is the transfer function (plotted above), the following two rows are ATaCR and NC ZZ Coherences.
# #### -You can clearly see here an indication that the fact the f-vector is a different length than the event fft used to make ZZ coherence may be the root cause of this artifact in the ZZ coherence plots.
# #### -It is important to note that the trend line shown below is made with a mean, not a median. The box plots are made with a median. This may be why the issue until now, when I made these plots with a median, has never been noticed.
# <img src="./NB_Assets/3.28.25/Z6.11.5836.0m.Normal.png" alt="A" width="600">

# %% [markdown]
# #### -Some more testing on may be needed but this is ultimately solved with:
# ####    1. Digging into the QC some more for this station (Z6.11) finding any bad event data.
# ####    2. Set the box plot code to mean instead of median and remake them.
