# %% [markdown]
# ## `Priorities:`
#
# #### `[1]` **Find out why the ATaCR correction plot outputs look like the corrections were never applied or are not working.**
#
# #### `[2]` **Get back to finishing the notebook for the complete ATaCR method with all intermediate analysis (tfs, coh, etc.).**

# %% [markdown]
# So I'll begin with the simplest theory, that it's just not plotting correctly and everything up to that is fine. A quick test for this is comparing with the ATaCR demo outputs in the github documentation.
#
# Below, the left is the plots from my build and on the right is the corrected events demo for the same station-event (M08A) pair from https://nfsi-canada.github.io/OBStools/atacr.html#tutorial.

# %% [markdown]
# ![demo_compare_staavg](znb_images/demo_compare_staavg.png)

# %% [markdown]
# ![demo_compare_staavg](znb_images/demo_compare_dayavg.png)

# %% [markdown]
# ![demo_compare_dayavg.png](attachment:demo_compare_dayavg.png)
