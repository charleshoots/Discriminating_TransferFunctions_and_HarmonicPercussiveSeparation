# %% [markdown]
# ## Tasks for week of 2.14.25:
# ## Notes:
# - ## [Done] QC the Noise channel coherences
#     <!-- #### Action: -->
#     #### - 2.12: Noise metrics folder now updated, able to run noise summaries now from 'station_page'
#     #### - [Done on 2.14] Run the 'station_page' script in noise_mode which builds summary plots of noise PSD and coherences for each component and cross-components, respectively.
#     - #### - [Done on 2.13] Hold off on 'station_page' until the noisecut data issue below is figured out so it runs over both events and noise all at once.
#     #### - 2.14: Noise pages are done
# - ## [Done] Check the data bug thing with NoiseCut plots.
#     #### - I know for a fact not all the data finished running through NoiseCut so that's a likely cause.
#     #### - 2.09:Confirmed HPS has now completely run all ..available.. events for all channels (yes, horizontals are done too).
#     #### - 2.10:Data issue that broke the HPS side of the stem plots is now fixed. It came from the mirror function not handling the file parity correctly.
#     - #### - This is a result of a broader issue with dead traces that haven't yet been quarantined in the NoiseCut dataset.
#     - #### - It doesn't effect data but it breaks plots and I should fix this at some point.
#     #### - 2.13:All event and noise metrics now updated, ready to run 'station_page'
# - ## [Done] Event Pre/Post Coherences
#     <!-- #### Action: -->
#     #### - This is built into the 'station_page' script if 'make_report_pdf' option is enabled, make sure it's on. This slows the code alot so start asap.
# - ## [Done] Not a task that was planned but make sure to rebuild the stem plots but do a variant that filters left/right of the notch. This will match better with AGU figs.
#     #### - 2.14: Done. Links to a PDF for both forms of the stem plots linked below
# - ## [...] Slice noise along deployment parameters, particularly water depth
#     <!-- #### Action: -->
#     #### - Run the 'slice_metrics' script which builds aggregate plots of any PSD or coherence across the entire data set sliced by different parameters.
#     #### - I've never pointed 'slice_metrics' at noise so will have to test it. (was built for event data)
#     #### - 2.12: I don't know if I'll find a time to do this task before the meeting.
# - ## [...] All the figs on the AGU poster
#     <!-- #### Action: -->
#     #### - Run all scripts in the 'AGU2025' package folder. Pretty quick. Maybe an hour.

# %% [markdown]
# ## Stem plots:
# ### - [LINK : Notched Stem Plots](znb_images/UpdatedData_1.31.25/_notched_stem_plots.pdf)
# ### - [LINK : Banded Stem Plots](znb_images/UpdatedData_1.31.25/_banded_stem_plots.pdf)
