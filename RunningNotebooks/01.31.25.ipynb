# %%
import os,sys;from pathlib import Path;sys.path.insert(0, str(Path(os.getcwd()).parent/'Notebooks'))
from imports import *

# %% [markdown]
# ____
# # || Tasks  from last week ||
# ____
# ## 1. Confirm all new data has been processed by ATaCR then follow up with hand-on QC of the update
#
# ## 2. Run new data through NoiseCut if it hasn’t been done yet
#
# ## 3. Reproduce the AGU figs (coherence scatters etc.) with the update to the dataset
#
# ## 4. Do the same for those stem plots
# ____
#
# # || Tasks planned for the week after that ||
# ____
# ### - By 2/3/25 morning, send an updated draft of the paper to Helen.
# ### - In particular, have the anatomy of the two methods written out and the supporting details for coherence as a useful metric in comparisons.
# ____
# # || Task for some point in the near future ||
# ____
# ### - Reach out to Amir and see if he’s open to joining my committee. If yes, have a brief chat with Rob thanking him for being on it.

# %% [markdown]
# ________
# # > First task: Confirm all new data has been processed by ATaCR then follow up with hand-on QC of the update
# ________
# ## Visual QC on spectra, phase, and coherence done
# ## i. Days on 7 stations were found not flagged by ATaCR with abberant spectra.
# ## ii. They have been manually quarantined at every level.
# ## iii. Each station still has atleast 10 days of good spectra
# ##  (I've always made sure to have extra days for this exact reason)
# ________
# ________
# ![QC_bad_days_2125.png](znb_images/QC_bad_days_2125.png)

# %% [markdown]
# ________
# ________
# # > Second task: Run new data through NC.
# ________
# ________
# # | Important |
# ## - Typing this up at 9am and it's still running new data through NoiseCut right now and likely will be half way at most by the meeting this afternoon 2pm.
#
# ## - As such, I won't have an update to the NoiseCut coherences before the meeting with the new dataset to match with the corresponding update to ATaCR.

# %% [markdown]
# ________
# ________
# # > Third task: Reproduce AGU figs
# ________
# ________

# %% [markdown]
# ![QC_bad_days_2125.png](znb_images/agu25_evcat_vs_13125_update.png)

# %% [markdown]
# ____
# ## [NOTE] Shown at the last meeting, above is the event distribution update that compares the event catalog used at AGU (top row) with the updated catalog (bottom row) which has a significantly higher station density for events aswell a predictable GR-distribution for magnitudes.
#
# ## --I'm showing this here again because it is important to understand some of the distinctions between the AGU figs and what we see in this update below.
# ____

# %% [markdown]
# ![update](znb_images/UpdatedData_1.31.25/coh.vs.coh.13125update.vs.agu.png)

# %% [markdown]
# # --------Updated 1/31/25:
# <!-- ![QC_bad_days_2125.png](znb_images/Scatter.Noisecut.ATaCR.ZZ.ZZ.ZZ.ZZ.bymag.and.notch.png) -->

# %% [markdown]
# ![update](znb_images/UpdatedData_1.31.25/mag_scatter_update_compare.png)

# %% [markdown]
# ____
# ____
# # --------From AGU25:
# <!-- ![QC_bad_days_2125.png](znb_images/Scatter.Noisecut.ATaCR.ZZ.ZZ.ZZ.ZZ.bymag.and.notch.png) -->

# %% [markdown]
# # --------Updated 1/31/25:
# <!-- ![QC_bad_days_2125.png](znb_images/Scatter.Noisecut.ATaCR.ZZ.ZZ.ZZ.ZZ.bymag.and.notch.png) -->

# %% [markdown]
# ________
# ________
# # > Fourth task: Stem plots.
# ________
# ________
