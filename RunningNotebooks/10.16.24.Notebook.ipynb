# %% [markdown]
# ### Again, these are sort of rough to peruse in this notebook in a comparative way. Maybe just download this PDF and view it outside your browser.
#
# ## Link: [10.16.24.ZZCoh.pdf](./znb_images/method_reports_byinstrument_101624/10.16.24.ZZCoh.pdf)

# %% [markdown]
# ## Z-Original | Z-Corrected Coherences from ATaCR
# ____

# %% [markdown]
# ______
# ## ACCSE (XO)
# ![AACSE.XO.atacr.png](./znb_images/method_reports_byinstrument_101624/AACSE.XO.atacr.png)
# ![AACSE.XO.hps.png](./znb_images/method_reports_byinstrument_101624/AACSE.XO.hps.png)
# ______

# %% [markdown]
# ______
# ## ALBACORE (2D)
# ![ALBACORE.2D.atacr.png](./znb_images/method_reports_byinstrument_101624/ALBACORE.2D.atacr.png)
# ![ALBACORE.2D.hps.png](./znb_images/method_reports_byinstrument_101624/ALBACORE.2D.hps.png)
# ______

# %% [markdown]
# ______
# ## BLANCO (X9)
# ![BLANCO.X9.atacr.png](./znb_images/method_reports_byinstrument_101624/BLANCO.X9.atacr.png)
# ![BLANCO.X9.hps.png](./znb_images/method_reports_byinstrument_101624/BLANCO.X9.hps.png)
# ______

# %% [markdown]
# ______
# ## CASCADIA INITIATIVE (7D)
# ![CASCADIA_INITIATIVE.7D.atacr.png](./znb_images/method_reports_byinstrument_101624/CASCADIA_INITIATIVE.7D.atacr.png)
# ![CASCADIA_INITIATIVE.7D.hps.png](./znb_images/method_reports_byinstrument_101624/CASCADIA_INITIATIVE.7D.hps.png)
# ______

# %% [markdown]
# ______
# ## CASCADIA KECK (7A)
# ![CASCADIA_KECK.7A.atacr.png](./znb_images/method_reports_byinstrument_101624/CASCADIA_KECK.7A.atacr.png)
# ![CASCADIA_KECK.7A.hps.png](./znb_images/method_reports_byinstrument_101624/CASCADIA_KECK.7A.hps.png)
# ______

# %% [markdown]
# ______
# ## ENAM (YO)
# ![ENAM.YO.atacr.png](./znb_images/method_reports_byinstrument_101624/ENAM.YO.atacr.png)
# ![ENAM.YO.hps.png](./znb_images/method_reports_byinstrument_101624/ENAM.YO.hps.png)
# ______

# %% [markdown]
# ______
# ## LAU BASIN EXPERIMENT (YL)
# ![LAU.YL.atacr.png](./znb_images/method_reports_byinstrument_101624/LAU.YL.atacr.png)
# ![LAU.YL.hps.png](./znb_images/method_reports_byinstrument_101624/LAU.YL.hps.png)
# ______

# %% [markdown]
# ______
# ## MARIANA EXPERIMENT (XF)
# ![MARIANA.XF.atacr.png](./znb_images/method_reports_byinstrument_101624/MARIANA.XF.atacr.png)
# ![MARIANA.XF.hps.png](./znb_images/method_reports_byinstrument_101624/MARIANA.XF.hps.png)
# ______

# %% [markdown]
# ______
# ## NOMELT EXPERIMENT (ZA)
# ![NOMELT.ZA.atacr.png](./znb_images/method_reports_byinstrument_101624/NOMELT.ZA.atacr.png)
# ![NOMELT.ZA.hps.png](./znb_images/method_reports_byinstrument_101624/NOMELT.ZA.hps.png)
# ______

# %% [markdown]
# ______
# ## PAPUA (ZN)
# ![PAPUA.ZN.atacr.png](./znb_images/method_reports_byinstrument_101624/PAPUA.ZN.atacr.png)
# ![PAPUA.ZN.hps.png](./znb_images/method_reports_byinstrument_101624/PAPUA.ZN.hps.png)
# ______

# %% [markdown]
# ______
# ## PLATE EXPERIMENT (Z6)
# ![PLATE.Z6.atacr.png](./znb_images/method_reports_byinstrument_101624/PLATE.Z6.atacr.png)
# ![PLATE.Z6.hps.png](./znb_images/method_reports_byinstrument_101624/PLATE.Z6.hps.png)
# ______
