# %% [markdown]
# ## Tasks for week of 02.17.25:
# #### - 1. Make a pre-AGU notebook clearly documenting with written narrative all the sanity checks done before AGU. What they are, what they show you, what you learned from it as a sanity check.
#         - That way you can easily adapt your notebook to the new results when you have it.
# #### - 2. Kill dead NoiseCut traces and corresponding source-receiver pair in ATaCR. This will be any trace that was downloaded with any amount of gap that lead to NC breaking.
# #### - 3. Kill bad noise and reconstitute 10-days good noise for each station that would be affected.
# #### - 4. QC the Noise, task from last week, build into a single summary notebook. Essentially, finish the plots that were built and take a moment to look at everything.

# %% [markdown]
# ## Stem plots:
# ### - [LINK : Notched Stem Plots](znb_images/UpdatedData_1.31.25/_notched_stem_plots.pdf)
# ### - [LINK : Banded Stem Plots](znb_images/UpdatedData_1.31.25/_banded_stem_plots.pdf)

# %% [markdown]
# Tasks for week of 02.17.25:
# 1. Make a pre-AGU notebook clearly documenting with written narrative all the sanity checks done before AGU. What they are, what they show you, what you learned from it as a sanity check.
#
# 2. Kill dead NoiseCut traces and corresponding source-receiver pair in ATaCR. This will be any trace that was downloaded with any amount of gap that lead to NC breaking.
#
# 3. Kill bad noise and reconstitute 10-days good noise for each station that would be affected.
#
# 4. QC the Noise, task from last week, build into a single summary notebook. Essentially, finish the plots that were built and take a moment to look at everything.
